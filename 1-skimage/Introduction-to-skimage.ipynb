# %%
import numpy as np
import skimage.io
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = skimage.io.imread('images/astronaut.jpg')

# %%
img
# Out:
# array([[[148, 139, 158],
#         [112, 103, 120],
#         [ 73,  65,  80],
#         ...,
#         [125, 116, 111],
#         [125, 116, 111],
#         [125, 116, 111]],
#
#        [[178, 169, 186],
#         [150, 141, 158],
#         [119, 111, 124],
#         ...,
#         [125, 116, 111],
#         [125, 116, 111],
#         [125, 116, 111]],
#
#        [[203, 195, 210],
#         [186, 178, 191],
#         [168, 160, 171],
#         ...,
#         [125, 116, 111],
#         [125, 116, 111],
#         [125, 116, 111]],
#
#        ...,
#
#        [[185, 170, 177],
#         [184, 169, 174],
#         [184, 167, 173],
#         ...,
#         [  3,   0,   0],
#         [  7,   3,   0],
#         [ 10,   6,   3]],
#
#        [[181, 168, 175],
#         [181, 169, 173],
#         [180, 165, 170],
#         ...,
#         [  9,   5,   2],
#         [ 10,   6,   3],
#         [  3,   0,   0]],
#
#        [[180, 167, 174],
#         [179, 167, 171],
#         [177, 162, 167],
# ...

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (512, 512, 3)

# %%
img1 = skimage.io.imread('images/colorwheel.jpg')
plt.imshow(img1)

# %%
img1.shape
# Out:
# (370, 371, 3)

# %%
r = img1[:,:,0] # red matrix
g = img1[:,:,1] # green
b = img1[:,:,2] # blue

# %%
r.shape
# Out:
# (370, 371)

# %%
plt.figure(figsize=(10,6))

plt.subplot(1,3,1)
plt.title("red")
plt.imshow(r,cmap='gray')

plt.subplot(1,3,2)
plt.title("green")
plt.imshow(g,cmap='gray')

plt.subplot(1,3,3)
plt.title("blue")
plt.imshow(b,cmap='gray')

plt.show()

plt.imshow(img1)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.subplot(1,3,1)
plt.imshow(r,cmap='Reds')
plt.subplot(1,3,2)
plt.imshow(g,cmap='Greens')
plt.subplot(1,3,3)
plt.imshow(b,cmap='Blues')
plt.show()
plt.imshow(img1)

# %%
plt.figure(figsize=(10,6))

plt.subplot(1,3,1)
plt.title("red")
plt.imshow(r)

plt.subplot(1,3,2)
plt.title("green")
plt.imshow(g)

plt.subplot(1,3,3)
plt.title("blue")
plt.imshow(b)

plt.show()

plt.imshow(img1)
plt.show()

# %% [markdown]
# # Convert Image into Gray Scale

# %%
import skimage.color

# %%
plt.imshow(img)

# %%
gray = skimage.color.rgb2gray(img)

# %%
img.shape
# Out:
# (512, 512, 3)

# %%
gray.shape
# Out:
# (512, 512)

# %%
plt.imshow(gray,cmap='gray')

# %%
skimage.io.imsave('images/astro_gray.png',gray)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %% [markdown]
# ##  Image Histogram

# %%
img4 = skimage.io.imread('images/landscape.jpg',as_gray=True)

# %%
plt.imshow(img4,cmap='gray')

# %%
img4.shape
# Out:
# (183, 275)

# %%
flatten_img = img4.ravel()

# %%
len(flatten_img)
# Out:
# 50325

# %%
plt.hist(flatten_img,bins=255)
plt.show()

# %%
flatten_img*100
# Out:
# array([58.03921569, 58.43137255, 57.25490196, ..., 56.8627451 ,
#        56.8627451 , 56.8627451 ])

# %%
plt.hist(flatten_img*100,bins=255)
plt.show()

# %% [markdown]
# ## Histogram Equalization

# %%
from skimage.exposure import equalize_hist

# %%
equalize_img = equalize_hist(img4)

# %%
plt.imshow(equalize_img,cmap='gray')

# %%
plt.hist(equalize_img.flatten(), bins=255)
plt.show()

# %%
skimage.io.imsave('images/landscape_hist_eq.png',equalize_img,)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %% [markdown]
# ## Image Resize

# %%
img5 = skimage.io.imread('images/coffee.jpg')

# %%
img5.shape
# Out:
# (400, 600, 3)

# %%
plt.imshow(img5)

# %%
import skimage.transform

# %%
img_r = skimage.transform.resize(img5,(200,300,3))

# %%
img_r.shape
# Out:
# (200, 300, 3)

# %%
plt.imshow(img_r)

# %%
img_r1 = skimage.transform.resize(img5,(800,1200,3))

# %%
img_r1.shape
# Out:
# (800, 1200, 3)

# %%
plt.imshow(img_r1)
